# %% [markdown]
# <a href="https://colab.research.google.com/github/lcn781/M14_SCRIPTING/blob/main/Mod14Tarefa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crie um script que receba uma lista de abreviaturas de meses (MAR, ABR, MAI,
# JUN, etc) como argumento e gera as pastas e gráficos necessários para os meses
# de referência.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys

sns.set_theme(style='whitegrid')



def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index, aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

print('O nome do nosso script é:', sys.argv[0])
mes = sys.argv[1]

print('Mes de referencia é:', sys.argv[1])



sinasc = pd.read_csv('/Users/luizcarvalho/Downloads/PYTHON/input/SINASC_RO_2019_'+mes+'.csv')

max_data = sinasc.DTNASC.max()[:7]
max_data

os.makedirs('./output/figs/'+max_data, exist_ok=True)

# 1 - Quantidade de nascimentos/Sexo
plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'count', 'quantidade de nascimento','data de nascimento', 'unstack')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento por data.png')

# 2 - Média Idade da Mãe/Sexo
plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

# 3 - Média Peso Bebe/Sexo
plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

# 4 - Média peso/Escolaridade Mãe
plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'peso','escolaridade mãe','sort')
plt.savefig('./output/figs/'+max_data+'/media peso por escolaridade mae.png')

# 5 - Apgar1/Gestação
plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

# 6 - Apgar5/Gestação
plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# O nome do nosso script é: /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py
# Mes de referencia é: -f
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_847/3876085614.py in <cell line: 0>()
#      30
#      31
# ---> 32 sinasc = pd.read_csv('/Users/luizcarvalho/Downloads/PYTHON/input/SINASC_RO_2019_'+mes+'.csv')
#      33
#      34 max_data = sinasc.DTNASC.max()[:7]
#
# ...
